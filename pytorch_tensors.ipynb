# %% [markdown]
# <a href="https://colab.research.google.com/github/Dorabb/Deeplearning-using-pytourch-practice/blob/main/pytorch_tensors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **torch-tensors**
# 1.   The torch package contains data structures for multi-dimensional tensors and mathematical ops over these tensors
# 2.   It provides many utilities for efficient serialization of Tensors and arbitrary types, and other utilities.

# %%
"""
is_tensor(obj, /) : Returns True if obj is a PyTorch tensor.

parameters: object to test
Return Type : Type[Tensor]

"""
import torch

x = torch.tensor([1, 2, 3])
torch.is_tensor(x)
